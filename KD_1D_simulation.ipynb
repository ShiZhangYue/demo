# %% [markdown]
# <a href="https://colab.research.google.com/github/ShiZhangYue/demo/blob/main/KD_1D_simulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
import torch.utils.data
import numpy as np
import pandas as pd
from torch.utils.data import TensorDataset,DataLoader


torch.manual_seed(0)
torch.cuda.manual_seed(0)

# %%
## Load data

train = np.array(pd.read_csv('1Ddata_train_ver2.csv'))
test = np.array(pd.read_csv('1Ddata_test_ver2.csv'))

X_train = train[:,0:-1].reshape((-1, 1, 256))
y_train = train[:,-1]
X_test = test[:,0:-1].reshape((-1, 1, 256))
y_test = test[:,-1]

train_dataset = TensorDataset(torch.Tensor(X_train), torch.Tensor(y_train).long())
test_dataset = TensorDataset(torch.Tensor(X_test), torch.Tensor(y_test).long())

batch_size = 50

dataloader = {"train": DataLoader(dataset=train_dataset,  # torch TensorDataset format
                                  batch_size=batch_size,  # mini batch size
                                  shuffle=True,
                                  num_workers=int(2),
                                  drop_last=True),
              "test": DataLoader(dataset=test_dataset,  # torch TensorDataset format
                                 batch_size=batch_size,  # mini batch size
                                 shuffle=True,
                                 num_workers=int(2),
                                 drop_last=False)}
classes = ('surface1', 'surface2', 'surface3')

# %%
class TeacherNet(nn.Module):
    def __init__(self):
        super(TeacherNet, self).__init__()
        
        # Instantiate two convolutional layers
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=16, kernel_size=3, stride=2, padding=1)
        # Instantiate dense layers
        self.fc1 = nn.Linear(16*128, 120)  #10x7x7 num_channel x height x width , orignal H/W 28 after two pooling, H/W = 7
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 3)
        # Instantiate the ReLU nonlinearity
        self.relu = nn.ReLU()        
        # Instantiate a max pooling layer
        self.pool = nn.MaxPool2d(2, 2)        

        
    def forward(self, x):

        # Apply conv followd by relu, then in next line pool
        x = self.relu(self.conv1(x))
        # Prepare the image for the fully connected layer
        x = torch.flatten(x, start_dim=1)
        x = self.fc1(x)
        x = self.fc2(x)       
        # Apply the fully connected layer and return the result
        return self.fc3(x)


def train_teacher(model, device, train_loader, optimizer, epoch):
    model.train()
    trained_samples = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.cross_entropy(output, target)
        loss.backward()
        optimizer.step()

        trained_samples += len(data)
        progress = math.ceil(batch_idx / len(train_loader) * 50)
        print("\rTrain epoch %d: %d/%d, [%-51s] %d%%" %
              (epoch, trained_samples, len(train_loader.dataset),
               '-' * progress + '>', progress * 2), end='')


def test_teacher(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.cross_entropy(output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest: average loss: {:.4f}, accuracy: {}/{} ({:.0f}%)'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return test_loss, correct / len(test_loader.dataset)

# %%
def teacher_main(dataloader):
    epochs = 60
    batch_size = 50
    torch.manual_seed(0)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # train_loader = torch.utils.data.DataLoader(
    #     datasets.MNIST('../data/MNIST', train=True, download=True,
    #                    transform=transforms.Compose([
    #                        transforms.ToTensor(),
    #                        transforms.Normalize((0.1307,), (0.3081,))
    #                    ])),
    #     batch_size=batch_size, shuffle=True)
    # test_loader = torch.utils.data.DataLoader(
    #     datasets.MNIST('../data/MNIST', train=False, download=True, transform=transforms.Compose([
    #         transforms.ToTensor(),
    #         transforms.Normalize((0.1307,), (0.3081,))
    #     ])),
    #     batch_size=1000, shuffle=True)

    model = TeacherNet().to(device)
    optimizer = torch.optim.Adam(model.parameters())
    
    teacher_history = []

    for epoch in range(1, epochs + 1):
        train_teacher(model, device, dataloader["train"], optimizer, epoch)
        loss, acc = test_teacher(model, device, dataloader["test"])
        
        teacher_history.append((loss, acc))

    torch.save(model.state_dict(), "teacher.pt")
    return model, teacher_history

# %%
# 训练教师网络

teacher_model, teacher_history = teacher_main(dataloader)
# Out:
# Train epoch 1: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 1.0468, accuracy: 217/449 (48%)
# Train epoch 2: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.8851, accuracy: 277/449 (62%)
# Train epoch 3: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.6409, accuracy: 329/449 (73%)
# Train epoch 4: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.4794, accuracy: 360/449 (80%)
# Train epoch 5: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.5542, accuracy: 318/449 (71%)
# Train epoch 6: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.4179, accuracy: 370/449 (82%)
# Train epoch 7: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.5307, accuracy: 328/449 (73%)
# Train epoch 8: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.5816, accuracy: 321/449 (71%)
# Train epoch 9: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.4063, accuracy: 367/449 (82%)
# Train epoch 10: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3906, accuracy: 381/449 (85%)
# Train epoch 11: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3893, accuracy: 369/449 (82%)
# Train epoch 12: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.5183, accuracy: 336/449 (75%)
# Train epoch 13: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3922, accuracy: 376/449 (84%)
# Train epoch 14: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.4281, accuracy: 358/449 (80%)
# Train epoch 15: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3960, accuracy: 366/449 (82%)
# Train epoch 16: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3774, accuracy: 373/449 (83%)
# Train epoch 17: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.5569, accuracy: 334/449 (74%)
# Train epoch 18: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.5871, accuracy: 328/449 (73%)
# Train epoch 19: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3934, accuracy: 366/449 (82%)
# Train epoch 20: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.4058, accuracy: 369/449 (82%)
# Train epoch 21: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3922, accuracy: 369/449 (82%)
# Train epoch 22: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3764, accuracy: 374/449 (83%)
# Train epoch 23: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.4604, accuracy: 352/449 (78%)
# Train epoch 24: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.4088, accuracy: 364/449 (81%)
# Train epoch 25: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.4285, accuracy: 357/449 (80%)
# Train epoch 26: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3908, accuracy: 371/449 (83%)
# Train epoch 27: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3783, accuracy: 376/449 (84%)
# Train epoch 28: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3759, accuracy: 372/449 (83%)
# Train epoch 29: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3911, accuracy: 370/449 (82%)
# Train epoch 30: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3802, accuracy: 371/449 (83%)
# Train epoch 31: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.4021, accuracy: 367/449 (82%)
# Train epoch 32: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.4366, accuracy: 357/449 (80%)
# Train epoch 33: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.4429, accuracy: 359/449 (80%)
# Train epoch 34: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3820, accuracy: 371/449 (83%)
# Train epoch 35: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3818, accuracy: 369/449 (82%)
# Train epoch 36: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3898, accuracy: 369/449 (82%)
# Train epoch 37: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.4519, accuracy: 358/449 (80%)
# Train epoch 38: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3971, accuracy: 364/449 (81%)
# Train epoch 39: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3776, accuracy: 375/449 (84%)
# Train epoch 40: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.4578, accuracy: 355/449 (79%)
# Train epoch 41: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3878, accuracy: 365/449 (81%)
# Train epoch 42: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.4007, accuracy: 371/449 (83%)
# Train epoch 43: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3873, accuracy: 370/449 (82%)
# Train epoch 44: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.5645, accuracy: 329/449 (73%)
# Train epoch 45: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.4089, accuracy: 369/449 (82%)
# Train epoch 46: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3868, accuracy: 367/449 (82%)
# Train epoch 47: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3885, accuracy: 370/449 (82%)
# Train epoch 48: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3810, accuracy: 371/449 (83%)
# Train epoch 49: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.5496, accuracy: 341/449 (76%)
# Train epoch 50: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.5417, accuracy: 333/449 (74%)
# Train epoch 51: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3885, accuracy: 368/449 (82%)
# Train epoch 52: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3811, accuracy: 372/449 (83%)
# Train epoch 53: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3825, accuracy: 373/449 (83%)
# Train epoch 54: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3790, accuracy: 375/449 (84%)
# Train epoch 55: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.4289, accuracy: 367/449 (82%)
# Train epoch 56: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3853, accuracy: 372/449 (83%)
# Train epoch 57: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.3865, accuracy: 372/449 (83%)
# Train epoch 58: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.4459, accuracy: 358/449 (80%)
# Train epoch 59: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.4310, accuracy: 362/449 (81%)
# Train epoch 60: 1000/1049, [------------------------------------------------>  ] 96%
# Test: average loss: 0.4033, accuracy: 366/449 (82%)

# %%
import numpy as np
from matplotlib import pyplot as plt

def softmax_t(x, t):
    x_exp = np.exp(x / t)
    return x_exp / np.sum(x_exp)

# test_loader_bs1 = torch.utils.data.DataLoader(
#     datasets.MNIST('../data/MNIST', train=False, download=True, transform=transforms.Compose([
#         transforms.ToTensor(),
#         transforms.Normalize((0.1307,), (0.3081,))
#     ])),
#     batch_size=1, shuffle=True)

# %%
teacher_model.eval()
with torch.no_grad():
    data, target = next(iter(dataloader["test"]))
    data, target = data.to('cuda'), target.to('cuda')
    output = teacher_model(data)

test_x = data.cpu().numpy()
y_out = output.cpu().numpy()
y_out = y_out[0, ::]
print('Output (NO softmax):', y_out)



# plt.subplot(3, 1, 1)
# plt.imshow(test_x[0, 0, ::])

plt.subplot(2, 1, 1)
plt.bar(list(range(3)), softmax_t(y_out, 1), width=0.3)

plt.subplot(2, 1, 2)
plt.bar(list(range(3)), softmax_t(y_out, 10), width=0.3)
plt.show()
# Out:
# Output (NO softmax): [ 0.7889232   0.10639326 -1.9247795 ]

# %%
class StudentNet(nn.Module):
    def __init__(self):
        super(StudentNet, self).__init__()
        self.fc1 = nn.Linear(256 * 1, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 3)

    def forward(self, x):
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
def distillation(y, labels, teacher_scores, temp, alpha):
    return nn.KLDivLoss()(F.log_softmax(y / temp, dim=1), F.softmax(teacher_scores / temp, dim=1)) * (
            temp * temp * 2.0 * alpha) + F.cross_entropy(y, labels) * (1. - alpha)

# %%
def train_student_kd(model, device, train_loader, optimizer, epoch):
    model.train()
    trained_samples = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        teacher_output = teacher_model(data)
        teacher_output = teacher_output.detach()  # 切断老师网络的反向传播，感谢B站“淡淡的落”的提醒
  
        pred = output.argmax(dim=1, keepdim=True)
        acc = 100.0 * torch.sum(pred.view(-1) == target)/len(target)

        #hyperpara temperature alpha
        loss = distillation(output, target, teacher_output, temp=5.0, alpha=0.7)
        loss.backward()
        optimizer.step()
        trained_samples += len(data)
        progress = math.ceil(batch_idx / len(train_loader) * 50)
        print("\rTrain epoch %d: %d/%d, [%-51s] %d%%" %
              (epoch, trained_samples, len(train_loader.dataset),
               '-' * progress + '>', progress * 2), end='')


    print(' Training loss {0:.4f}, Training accuracy {1:.2f}%'.format (loss.item(),acc))

def test_student_kd(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.cross_entropy(output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('Test: average loss: {:.4f}, accuracy: {}/{} ({:.0f}%)'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return test_loss, correct / len(test_loader.dataset)

# %%
def student_kd_main(dataloader):
    epochs = 60
    batch_size = 50
    torch.manual_seed(0)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # train_loader = torch.utils.data.DataLoader(
    #     datasets.MNIST('../data/MNIST', train=True, download=True,
    #                    transform=transforms.Compose([
    #                        transforms.ToTensor(),
    #                        transforms.Normalize((0.1307,), (0.3081,))
    #                    ])),
    #     batch_size=batch_size, shuffle=True)
    # test_loader = torch.utils.data.DataLoader(
    #     datasets.MNIST('../data/MNIST', train=False, download=True, transform=transforms.Compose([
    #         transforms.ToTensor(),
    #         transforms.Normalize((0.1307,), (0.3081,))
    #     ])),
    #     batch_size=1000, shuffle=True)

    model = StudentNet().to(device)
    optimizer = torch.optim.Adam(model.parameters())
    
    student_history = []
    for epoch in range(1, epochs + 1):
        train_student_kd(model, device, dataloader['train'], optimizer, epoch)
        loss, acc = test_student_kd(model, device, dataloader['test'])
        student_history.append((loss, acc))

    torch.save(model.state_dict(), "student_kd.pt")
    return model, student_history

# %%
student_kd_model, student_kd_history = student_kd_main(dataloader)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2748: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   "reduction: 'mean' divides the total loss by both the batch size and the support size."
# Train epoch 1: 1000/1049, [------------------------------------------------>  ] 96% Training loss 3.5057, Training accuracy 30.00%
# Test: average loss: 1.0910, accuracy: 149/449 (33%)
# Train epoch 2: 1000/1049, [------------------------------------------------>  ] 96% Training loss 3.1102, Training accuracy 54.00%
# Test: average loss: 1.0489, accuracy: 216/449 (48%)
# Train epoch 3: 1000/1049, [------------------------------------------------>  ] 96% Training loss 2.7717, Training accuracy 52.00%
# Test: average loss: 0.9678, accuracy: 222/449 (49%)
# Train epoch 4: 1000/1049, [------------------------------------------------>  ] 96% Training loss 2.7970, Training accuracy 50.00%
# Test: average loss: 0.8915, accuracy: 249/449 (55%)
# Train epoch 5: 1000/1049, [------------------------------------------------>  ] 96% Training loss 2.2745, Training accuracy 58.00%
# Test: average loss: 1.0806, accuracy: 219/449 (49%)
# Train epoch 6: 1000/1049, [------------------------------------------------>  ] 96% Training loss 2.2842, Training accuracy 54.00%
# Test: average loss: 1.0593, accuracy: 242/449 (54%)
# Train epoch 7: 1000/1049, [------------------------------------------------>  ] 96% Training loss 2.0657, Training accuracy 64.00%
# Test: average loss: 1.0370, accuracy: 253/449 (56%)
# Train epoch 8: 1000/1049, [------------------------------------------------>  ] 96% Training loss 1.6342, Training accuracy 50.00%
# Test: average loss: 1.0238, accuracy: 263/449 (59%)
# Train epoch 9: 1000/1049, [------------------------------------------------>  ] 96% Training loss 1.4845, Training accuracy 68.00%
# Test: average loss: 0.9489, accuracy: 277/449 (62%)
# Train epoch 10: 1000/1049, [------------------------------------------------>  ] 96% Training loss 1.2159, Training accuracy 68.00%
# Test: average loss: 0.9420, accuracy: 286/449 (64%)
# Train epoch 11: 1000/1049, [------------------------------------------------>  ] 96% Training loss 1.0894, Training accuracy 60.00%
# Test: average loss: 0.8239, accuracy: 286/449 (64%)
# Train epoch 12: 1000/1049, [------------------------------------------------>  ] 96% Training loss 1.2992, Training accuracy 56.00%
# Test: average loss: 0.9610, accuracy: 293/449 (65%)
# Train epoch 13: 1000/1049, [------------------------------------------------>  ] 96% Training loss 1.3451, Training accuracy 68.00%
# Test: average loss: 0.8370, accuracy: 299/449 (67%)
# Train epoch 14: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.8829, Training accuracy 74.00%
# Test: average loss: 0.7191, accuracy: 316/449 (70%)
# Train epoch 15: 1000/1049, [------------------------------------------------>  ] 96% Training loss 1.1711, Training accuracy 62.00%
# Test: average loss: 0.7886, accuracy: 309/449 (69%)
# Train epoch 16: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5656, Training accuracy 74.00%
# Test: average loss: 0.7467, accuracy: 315/449 (70%)
# Train epoch 17: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.8543, Training accuracy 68.00%
# Test: average loss: 0.7072, accuracy: 320/449 (71%)
# Train epoch 18: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6073, Training accuracy 74.00%
# Test: average loss: 0.6670, accuracy: 319/449 (71%)
# Train epoch 19: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.4950, Training accuracy 86.00%
# Test: average loss: 0.6649, accuracy: 321/449 (71%)
# Train epoch 20: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.7513, Training accuracy 68.00%
# Test: average loss: 0.6595, accuracy: 321/449 (71%)
# Train epoch 21: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5748, Training accuracy 80.00%
# Test: average loss: 0.9172, accuracy: 297/449 (66%)
# Train epoch 22: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5749, Training accuracy 76.00%
# Test: average loss: 0.6590, accuracy: 325/449 (72%)
# Train epoch 23: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.7025, Training accuracy 68.00%
# Test: average loss: 0.6715, accuracy: 313/449 (70%)
# Train epoch 24: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.7453, Training accuracy 76.00%
# Test: average loss: 0.7613, accuracy: 323/449 (72%)
# Train epoch 25: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.8558, Training accuracy 74.00%
# Test: average loss: 0.6610, accuracy: 325/449 (72%)
# Train epoch 26: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6688, Training accuracy 80.00%
# Test: average loss: 0.6868, accuracy: 331/449 (74%)
# Train epoch 27: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.8004, Training accuracy 66.00%
# Test: average loss: 0.6593, accuracy: 326/449 (73%)
# Train epoch 28: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5615, Training accuracy 78.00%
# Test: average loss: 0.6597, accuracy: 326/449 (73%)
# Train epoch 29: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.7296, Training accuracy 62.00%
# Test: average loss: 0.6623, accuracy: 320/449 (71%)
# Train epoch 30: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6327, Training accuracy 84.00%
# Test: average loss: 0.6539, accuracy: 326/449 (73%)
# Train epoch 31: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5739, Training accuracy 82.00%
# Test: average loss: 0.6541, accuracy: 317/449 (71%)
# Train epoch 32: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.9108, Training accuracy 72.00%
# Test: average loss: 0.6581, accuracy: 318/449 (71%)
# Train epoch 33: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5402, Training accuracy 74.00%
# Test: average loss: 0.6761, accuracy: 332/449 (74%)
# Train epoch 34: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6970, Training accuracy 70.00%
# Test: average loss: 0.6595, accuracy: 316/449 (70%)
# Train epoch 35: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5415, Training accuracy 72.00%
# Test: average loss: 0.7036, accuracy: 328/449 (73%)
# Train epoch 36: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6155, Training accuracy 72.00%
# Test: average loss: 0.7095, accuracy: 331/449 (74%)
# Train epoch 37: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5632, Training accuracy 78.00%
# Test: average loss: 0.6565, accuracy: 317/449 (71%)
# Train epoch 38: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6796, Training accuracy 74.00%
# Test: average loss: 0.6667, accuracy: 327/449 (73%)
# Train epoch 39: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5502, Training accuracy 68.00%
# Test: average loss: 0.6579, accuracy: 317/449 (71%)
# Train epoch 40: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.8072, Training accuracy 74.00%
# Test: average loss: 0.7256, accuracy: 329/449 (73%)
# Train epoch 41: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.7063, Training accuracy 78.00%
# Test: average loss: 0.6470, accuracy: 326/449 (73%)
# Train epoch 42: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5868, Training accuracy 78.00%
# Test: average loss: 0.8149, accuracy: 316/449 (70%)
# Train epoch 43: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.7082, Training accuracy 68.00%
# Test: average loss: 0.6577, accuracy: 330/449 (73%)
# Train epoch 44: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6412, Training accuracy 68.00%
# Test: average loss: 0.6709, accuracy: 312/449 (69%)
# Train epoch 45: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.7547, Training accuracy 70.00%
# Test: average loss: 0.6759, accuracy: 333/449 (74%)
# Train epoch 46: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.9149, Training accuracy 60.00%
# Test: average loss: 0.6736, accuracy: 331/449 (74%)
# Train epoch 47: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.7991, Training accuracy 72.00%
# Test: average loss: 0.6510, accuracy: 319/449 (71%)
# Train epoch 48: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6956, Training accuracy 72.00%
# Test: average loss: 0.7567, accuracy: 330/449 (73%)
# Train epoch 49: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6564, Training accuracy 76.00%
# Test: average loss: 0.7910, accuracy: 321/449 (71%)
# Train epoch 50: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6048, Training accuracy 76.00%
# Test: average loss: 0.6494, accuracy: 319/449 (71%)
# Train epoch 51: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.4532, Training accuracy 88.00%
# Test: average loss: 0.7479, accuracy: 328/449 (73%)
# Train epoch 52: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6071, Training accuracy 82.00%
# Test: average loss: 0.6626, accuracy: 331/449 (74%)
# Train epoch 53: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5879, Training accuracy 78.00%
# Test: average loss: 0.6896, accuracy: 311/449 (69%)
# Train epoch 54: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.7424, Training accuracy 72.00%
# Test: average loss: 0.7553, accuracy: 331/449 (74%)
# Train epoch 55: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5665, Training accuracy 70.00%
# Test: average loss: 0.6427, accuracy: 325/449 (72%)
# Train epoch 56: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.8303, Training accuracy 70.00%
# Test: average loss: 0.7682, accuracy: 329/449 (73%)
# Train epoch 57: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6732, Training accuracy 68.00%
# Test: average loss: 0.6406, accuracy: 326/449 (73%)
# Train epoch 58: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6282, Training accuracy 78.00%
# Test: average loss: 0.6738, accuracy: 333/449 (74%)
# Train epoch 59: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.7339, Training accuracy 62.00%
# Test: average loss: 0.6557, accuracy: 333/449 (74%)
# Train epoch 60: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5918, Training accuracy 76.00%
# Test: average loss: 0.7736, accuracy: 322/449 (72%)

# %%
## 让学生自己学，不使用KD
def train_student(model, device, train_loader, optimizer, epoch):
    model.train()
    trained_samples = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        pred = output.argmax(dim=1, keepdim=True)
        acc = 100.0 * torch.sum(pred.view(-1) == target)/len(target)
        # print(output)
        # a
        loss = F.cross_entropy(output, target)
        loss.backward()
        optimizer.step()

        trained_samples += len(data)
        progress = math.ceil(batch_idx / len(train_loader) * 50)
        print("\rTrain epoch %d: %d/%d, [%-51s] %d%%" %
              (epoch, trained_samples, len(train_loader.dataset),
               '-' * progress + '>', progress * 2), end='')
        
    print(' Training loss {0:.4f}, Training accuracy {1:.2f}%'.format (loss.item(),acc))

def test_student(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.cross_entropy(output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('Test: average loss: {:.4f}, accuracy: {}/{} ({:.0f}%)'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return test_loss, correct / len(test_loader.dataset)

# %%
def student_main(dataloader):
  epochs = 60
  batch_size = 50
  torch.manual_seed(0)

  device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

  # train_loader = torch.utils.data.DataLoader(
  #     datasets.MNIST('../data/MNIST', train=True, download=True,
  #                     transform=transforms.Compose([
  #                         transforms.ToTensor(),
  #                         transforms.Normalize((0.1307,), (0.3081,))
  #                     ])),
  #     batch_size=batch_size, shuffle=True)
  # test_loader = torch.utils.data.DataLoader(
  #     datasets.MNIST('../data/MNIST', train=False, download=True, transform=transforms.Compose([
  #         transforms.ToTensor(),
  #         transforms.Normalize((0.1307,), (0.3081,))
  #     ])),
  #     batch_size=1000, shuffle=True)

  model = StudentNet().to(device)
  optimizer = torch.optim.Adam(model.parameters())

  student_history = []

  for epoch in range(1, epochs + 1):
      train_student(model, device, dataloader['train'], optimizer, epoch)
      loss, acc = test_student(model, device, dataloader['test'])
      student_history.append((loss, acc))

  torch.save(model.state_dict(), "student.pt")
  return model, student_history

# %%
student_simple_model, student_simple_history = student_main(dataloader)
# Out:
# Train epoch 1: 1000/1049, [------------------------------------------------>  ] 96% Training loss 1.0974, Training accuracy 30.00%
# Test: average loss: 1.0936, accuracy: 149/449 (33%)
# Train epoch 2: 1000/1049, [------------------------------------------------>  ] 96% Training loss 1.0667, Training accuracy 46.00%
# Test: average loss: 1.0630, accuracy: 234/449 (52%)
# Train epoch 3: 1000/1049, [------------------------------------------------>  ] 96% Training loss 1.0007, Training accuracy 52.00%
# Test: average loss: 1.0030, accuracy: 238/449 (53%)
# Train epoch 4: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.9401, Training accuracy 54.00%
# Test: average loss: 0.9363, accuracy: 247/449 (55%)
# Train epoch 5: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.8454, Training accuracy 60.00%
# Test: average loss: 0.8828, accuracy: 245/449 (55%)
# Train epoch 6: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.7833, Training accuracy 72.00%
# Test: average loss: 0.8226, accuracy: 276/449 (61%)
# Train epoch 7: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.7684, Training accuracy 66.00%
# Test: average loss: 0.8857, accuracy: 249/449 (55%)
# Train epoch 8: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6983, Training accuracy 70.00%
# Test: average loss: 0.7773, accuracy: 263/449 (59%)
# Train epoch 9: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.7511, Training accuracy 68.00%
# Test: average loss: 0.7184, accuracy: 298/449 (66%)
# Train epoch 10: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5846, Training accuracy 78.00%
# Test: average loss: 0.7269, accuracy: 295/449 (66%)
# Train epoch 11: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6650, Training accuracy 70.00%
# Test: average loss: 0.7198, accuracy: 283/449 (63%)
# Train epoch 12: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.7219, Training accuracy 56.00%
# Test: average loss: 0.7271, accuracy: 297/449 (66%)
# Train epoch 13: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.7259, Training accuracy 70.00%
# Test: average loss: 0.6491, accuracy: 316/449 (70%)
# Train epoch 14: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6675, Training accuracy 74.00%
# Test: average loss: 0.6420, accuracy: 324/449 (72%)
# Train epoch 15: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6885, Training accuracy 66.00%
# Test: average loss: 0.6579, accuracy: 311/449 (69%)
# Train epoch 16: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.4824, Training accuracy 76.00%
# Test: average loss: 0.6229, accuracy: 331/449 (74%)
# Train epoch 17: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6717, Training accuracy 72.00%
# Test: average loss: 0.6138, accuracy: 321/449 (71%)
# Train epoch 18: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5817, Training accuracy 66.00%
# Test: average loss: 0.6156, accuracy: 329/449 (73%)
# Train epoch 19: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5097, Training accuracy 74.00%
# Test: average loss: 0.6428, accuracy: 299/449 (67%)
# Train epoch 20: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6118, Training accuracy 76.00%
# Test: average loss: 0.6140, accuracy: 331/449 (74%)
# Train epoch 21: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6440, Training accuracy 68.00%
# Test: average loss: 0.6006, accuracy: 322/449 (72%)
# Train epoch 22: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5594, Training accuracy 72.00%
# Test: average loss: 0.7059, accuracy: 302/449 (67%)
# Train epoch 23: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6268, Training accuracy 68.00%
# Test: average loss: 0.6750, accuracy: 299/449 (67%)
# Train epoch 24: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.7393, Training accuracy 60.00%
# Test: average loss: 0.6266, accuracy: 308/449 (69%)
# Train epoch 25: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6043, Training accuracy 80.00%
# Test: average loss: 0.6579, accuracy: 312/449 (69%)
# Train epoch 26: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5110, Training accuracy 80.00%
# Test: average loss: 0.6239, accuracy: 326/449 (73%)
# Train epoch 27: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6660, Training accuracy 68.00%
# Test: average loss: 0.6140, accuracy: 315/449 (70%)
# Train epoch 28: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.4661, Training accuracy 84.00%
# Test: average loss: 0.5939, accuracy: 332/449 (74%)
# Train epoch 29: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5581, Training accuracy 64.00%
# Test: average loss: 0.6013, accuracy: 333/449 (74%)
# Train epoch 30: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5864, Training accuracy 76.00%
# Test: average loss: 0.6424, accuracy: 310/449 (69%)
# Train epoch 31: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.4754, Training accuracy 80.00%
# Test: average loss: 0.6043, accuracy: 315/449 (70%)
# Train epoch 32: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6166, Training accuracy 72.00%
# Test: average loss: 0.6461, accuracy: 305/449 (68%)
# Train epoch 33: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.4782, Training accuracy 74.00%
# Test: average loss: 0.5953, accuracy: 333/449 (74%)
# Train epoch 34: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5852, Training accuracy 68.00%
# Test: average loss: 0.5893, accuracy: 327/449 (73%)
# Train epoch 35: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5144, Training accuracy 68.00%
# Test: average loss: 0.5979, accuracy: 316/449 (70%)
# Train epoch 36: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5565, Training accuracy 74.00%
# Test: average loss: 0.6691, accuracy: 313/449 (70%)
# Train epoch 37: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5233, Training accuracy 76.00%
# Test: average loss: 0.5849, accuracy: 326/449 (73%)
# Train epoch 38: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5456, Training accuracy 74.00%
# Test: average loss: 0.5881, accuracy: 322/449 (72%)
# Train epoch 39: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.7347, Training accuracy 66.00%
# Test: average loss: 0.6111, accuracy: 314/449 (70%)
# Train epoch 40: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6912, Training accuracy 64.00%
# Test: average loss: 0.5884, accuracy: 322/449 (72%)
# Train epoch 41: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.4490, Training accuracy 82.00%
# Test: average loss: 0.6272, accuracy: 322/449 (72%)
# Train epoch 42: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5050, Training accuracy 74.00%
# Test: average loss: 0.6032, accuracy: 334/449 (74%)
# Train epoch 43: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6925, Training accuracy 66.00%
# Test: average loss: 0.5871, accuracy: 323/449 (72%)
# Train epoch 44: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5892, Training accuracy 68.00%
# Test: average loss: 0.5995, accuracy: 319/449 (71%)
# Train epoch 45: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6473, Training accuracy 66.00%
# Test: average loss: 0.5953, accuracy: 321/449 (71%)
# Train epoch 46: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.8286, Training accuracy 54.00%
# Test: average loss: 0.7009, accuracy: 305/449 (68%)
# Train epoch 47: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5891, Training accuracy 80.00%
# Test: average loss: 0.5821, accuracy: 328/449 (73%)
# Train epoch 48: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6383, Training accuracy 72.00%
# Test: average loss: 0.5964, accuracy: 334/449 (74%)
# Train epoch 49: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5852, Training accuracy 76.00%
# Test: average loss: 0.6575, accuracy: 313/449 (70%)
# Train epoch 50: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.4711, Training accuracy 80.00%
# Test: average loss: 0.5789, accuracy: 331/449 (74%)
# Train epoch 51: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.4601, Training accuracy 88.00%
# Test: average loss: 0.5897, accuracy: 335/449 (75%)
# Train epoch 52: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.4868, Training accuracy 78.00%
# Test: average loss: 0.6347, accuracy: 320/449 (71%)
# Train epoch 53: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.4835, Training accuracy 78.00%
# Test: average loss: 0.6162, accuracy: 315/449 (70%)
# Train epoch 54: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.7108, Training accuracy 68.00%
# Test: average loss: 0.5979, accuracy: 316/449 (70%)
# Train epoch 55: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5577, Training accuracy 74.00%
# Test: average loss: 0.5876, accuracy: 335/449 (75%)
# Train epoch 56: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6030, Training accuracy 74.00%
# Test: average loss: 0.5939, accuracy: 336/449 (75%)
# Train epoch 57: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6650, Training accuracy 64.00%
# Test: average loss: 0.5910, accuracy: 324/449 (72%)
# Train epoch 58: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5054, Training accuracy 78.00%
# Test: average loss: 0.5856, accuracy: 336/449 (75%)
# Train epoch 59: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.6579, Training accuracy 74.00%
# Test: average loss: 0.6172, accuracy: 320/449 (71%)
# Train epoch 60: 1000/1049, [------------------------------------------------>  ] 96% Training loss 0.5763, Training accuracy 76.00%
# Test: average loss: 0.6360, accuracy: 316/449 (70%)

# %%
import matplotlib.pyplot as plt
epochs = 60

x = list(range(1, epochs+1))

#multiple plots in 1 fig
fig,ax=plt.subplots(2,1,figsize=(12,12),dpi=80)


ax[0].plot([teacher_history[i][1] for i in range(epochs)], label='teacher')
ax[0].plot([student_kd_history[i][1] for i in range(epochs)], label='student with KD')
ax[0].plot([student_simple_history[i][1] for i in range(epochs)], label='student without KD')

ax[0].set_title('Test accuracy')
ax[0].legend()


# plt.subplot(2, 1, 2)
ax[1].plot([teacher_history[i][0] for i in range(epochs)], label='teacher')
ax[1].plot([student_kd_history[i][0] for i in range(epochs)], label='student with KD')
ax[1].plot([student_simple_history[i][0] for i in range(epochs)], label='student without KD')

ax[1].set_title('Test loss')
ax[1].legend()
